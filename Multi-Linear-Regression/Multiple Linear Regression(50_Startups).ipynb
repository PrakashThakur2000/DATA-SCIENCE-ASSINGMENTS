# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.set_style(style='darkgrid')
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.describe(include=object)
# Out:
#            State
# count         50
# unique         3
# top     New York
# freq          17

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'R&D Spend'}>,
#         <Axes: title={'center': 'Administration'}>],
#        [<Axes: title={'center': 'Marketing Spend'}>,
#         <Axes: title={'center': 'Profit'}>]], dtype=object)

# %% [markdown]
# # TRANFORMATION

# %%
TR=pd.get_dummies(data=df,columns=['State'])
TR
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0   165349.20       136897.80        471784.10  192261.83                 0
# 1   162597.70       151377.59        443898.53  191792.06                 1
# 2   153441.51       101145.55        407934.54  191050.39                 0
# 3   144372.41       118671.85        383199.62  182901.99                 0
# 4   142107.34        91391.77        366168.42  166187.94                 0
# 5   131876.90        99814.71        362861.36  156991.12                 0
# 6   134615.46       147198.87        127716.82  156122.51                 1
# 7   130298.13       145530.06        323876.68  155752.60                 0
# 8   120542.52       148718.95        311613.29  152211.77                 0
# 9   123334.88       108679.17        304981.62  149759.96                 1
# 10  101913.08       110594.11        229160.95  146121.95                 0
# ...

# %%
df.rename(columns={'R&D Spend':'RDSpend'},inplace=True)

# %%
df.rename(columns={'Marketing Spend':'MSpend'},inplace=True)

# %%
from sklearn .preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
sc.fit_transform(TR)
# Out:
# array([[ 2.01641149e+00,  5.60752915e-01,  2.15394309e+00,
#          2.01120333e+00, -7.17740563e-01, -6.85994341e-01,
#          1.39326109e+00],
#        [ 1.95586034e+00,  1.08280658e+00,  1.92360040e+00,
#          1.99942997e+00,  1.39326109e+00, -6.85994341e-01,
#         -7.17740563e-01],
#        [ 1.75436374e+00, -7.28257028e-01,  1.62652767e+00,
#          1.98084225e+00, -7.17740563e-01,  1.45773797e+00,
#         -7.17740563e-01],
#        [ 1.55478369e+00, -9.63646307e-02,  1.42221024e+00,
#          1.77662724e+00, -7.17740563e-01, -6.85994341e-01,
#          1.39326109e+00],
#        [ 1.50493720e+00, -1.07991935e+00,  1.28152771e+00,
#          1.35774012e+00, -7.17740563e-01,  1.45773797e+00,
#         -7.17740563e-01],
#        [ 1.27980001e+00, -7.76239071e-01,  1.25421046e+00,
#          1.12724963e+00, -7.17740563e-01, -6.85994341e-01,
#          1.39326109e+00],
#        [ 1.34006641e+00,  9.32147208e-01, -6.88149930e-01,
# ...

# %%
df2=pd.DataFrame(sc.fit_transform(TR),columns=TR.columns)
df2
# Out:
#     R&D Spend  Administration  Marketing Spend    Profit  State_California  \
# 0    2.016411        0.560753         2.153943  2.011203         -0.717741
# 1    1.955860        1.082807         1.923600  1.999430          1.393261
# 2    1.754364       -0.728257         1.626528  1.980842         -0.717741
# 3    1.554784       -0.096365         1.422210  1.776627         -0.717741
# 4    1.504937       -1.079919         1.281528  1.357740         -0.717741
# 5    1.279800       -0.776239         1.254210  1.127250         -0.717741
# 6    1.340066        0.932147        -0.688150  1.105481          1.393261
# 7    1.245057        0.871980         0.932186  1.096210         -0.717741
# 8    1.030369        0.986952         0.830887  1.007470         -0.717741
# 9    1.091819       -0.456640         0.776107  0.946022          1.393261
# 10   0.620398       -0.387599         0.149807  0.854847         -0.717741
# ...

# %% [markdown]
# # Model building

# %%
import statsmodels.formula.api as smf

# %%
df3=df.drop(columns=['State'])

# %%
df3
# Out:
#       RDSpend  Administration     MSpend     Profit
# 0   165349.20       136897.80  471784.10  192261.83
# 1   162597.70       151377.59  443898.53  191792.06
# 2   153441.51       101145.55  407934.54  191050.39
# 3   144372.41       118671.85  383199.62  182901.99
# 4   142107.34        91391.77  366168.42  166187.94
# 5   131876.90        99814.71  362861.36  156991.12
# 6   134615.46       147198.87  127716.82  156122.51
# 7   130298.13       145530.06  323876.68  155752.60
# 8   120542.52       148718.95  311613.29  152211.77
# 9   123334.88       108679.17  304981.62  149759.96
# 10  101913.08       110594.11  229160.95  146121.95
# 11  100671.96        91790.61  249744.55  144259.40
# 12   93863.75       127320.38  249839.44  141585.52
# 13   91992.39       135495.07  252664.93  134307.35
# 14  119943.24       156547.42  256512.92  132602.65
# 15  114523.61       122616.84  261776.23  129917.04
# 16   78013.11       121597.55  264346.06  126992.93
# ...

# %%
Scaled_data=pd.DataFrame(sc.fit_transform(df3),columns=df3.columns)
Scaled_data
# Out:
#      RDSpend  Administration    MSpend    Profit
# 0   2.016411        0.560753  2.153943  2.011203
# 1   1.955860        1.082807  1.923600  1.999430
# 2   1.754364       -0.728257  1.626528  1.980842
# 3   1.554784       -0.096365  1.422210  1.776627
# 4   1.504937       -1.079919  1.281528  1.357740
# 5   1.279800       -0.776239  1.254210  1.127250
# 6   1.340066        0.932147 -0.688150  1.105481
# 7   1.245057        0.871980  0.932186  1.096210
# 8   1.030369        0.986952  0.830887  1.007470
# 9   1.091819       -0.456640  0.776107  0.946022
# 10  0.620398       -0.387599  0.149807  0.854847
# 11  0.593085       -1.065540  0.319834  0.808168
# 12  0.443260        0.215449  0.320617  0.741155
# 13  0.402078        0.510179  0.343957  0.558750
# 14  1.017181        1.269199  0.375742  0.516026
# 15  0.897913        0.045868  0.419219  0.448720
# 16  0.094441        0.009118  0.440446  0.375436
# 17  0.460720        0.855666  0.591017  0.334771
# ...

# %%
model=smf.ols('Profit~RDSpend+Administration+MSpend',data=Scaled_data).fit()
model

# %%
model.params
# Out:
# Intercept        -5.204170e-16
# RDSpend           9.175798e-01
# Administration   -1.864043e-02
# MSpend            8.261087e-02
# dtype: float64

# %%
model.rsquared
# Out:
# 0.9507459940683246

# %%
model.rsquared_adj
# Out:
# 0.9475337762901719
