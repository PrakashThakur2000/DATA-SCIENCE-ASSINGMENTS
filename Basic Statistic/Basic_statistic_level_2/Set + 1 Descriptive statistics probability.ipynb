# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Q1) Look at the data given below. Plot the data, find the outliers and find out  μ,σ,σ^2

# %%
df=np.array([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,
           39.42,26.71,35.00])
df
# Out:
# array([24.23, 25.53, 25.41, 24.14, 29.62, 28.25, 25.81, 24.39, 40.26,
#        32.95, 91.36, 25.99, 39.42, 26.71, 35.  ])

# %%
names=["Allied Signal","Bankers Trust","General Mills","ITT Industries","J.P.Morgan & Co.",
       "Lehman Brothers","Marriott","MCI","Merrill Lync","Microsoft","morgan Stanley",
       "Sun Microsystems","Travelers","US Airways","Warner-Lambert"]
names
# Out:
# ['Allied Signal',
#  'Bankers Trust',
#  'General Mills',
#  'ITT Industries',
#  'J.P.Morgan & Co.',
#  'Lehman Brothers',
#  'Marriott',
#  'MCI',
#  'Merrill Lync',
#  'Microsoft',
#  'morgan Stanley',
#  'Sun Microsystems',
#  'Travelers',
#  'US Airways',
#  'Warner-Lambert']

# %%
plt.pie(df,labels=names,autopct='%0.1f%%',radius=1.5)
plt.show()

# %%
# for showing outliers
sns.boxplot(x=df)

plt.show()

# %%
df.mean()
# Out:
# 33.27133333333333

# %%
df.std()
# Out:
# 16.370812590976932

# %%
df.var()
# Out:
# 268.00350488888887
